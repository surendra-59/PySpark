# %% [markdown]
# ##### 1. Filtering Rows (filter() / where())

# %%
# Syntax:

df.filter(condition)

# or

df.where(condition)
# Both are exactly the same.

# %%
# Sample Data
from pyspark.sql import Row

data = [
    Row(emp_id=101, name="Alice", age=25, salary=50000, dept="HR"),
    Row(emp_id=102, name="Bob", age=30, salary=70000, dept="IT"),
    Row(emp_id=103, name="Charlie", age=35, salary=90000, dept="IT"),
    Row(emp_id=104, name="David", age=28, salary=45000, dept="Finance"),
    Row(emp_id=105, name="Eva", age=40, salary=100000, dept="HR")
]

df = spark.createDataFrame(data)

df.show()

# %%
# Filter salary greater than 60000

from pyspark.sql.functions import col

df.filter(col("salary") > 60000).show()

# %%
# Filter department
df.filter(col("dept") == "IT").show()

# %%
# Multiple Conditions (AND)
df.filter(
    (col("salary") > 60000) &
    (col("age") > 30)
).show()

# %%
# Multiple Conditions (OR)
df.filter(
    (col("dept") == "HR") |
    (col("dept") == "Finance")
).show()

# %%
# NOT
df.filter(~(col("dept") == "HR")).show()

# %%
# isin()
df.filter(col("dept").isin("HR","IT")).show()

# %%
# String contains
df.filter(col("name").contains("a")).show()

# %%
# startswith

df.filter(col("name").startswith("A")).show()

# %%
# endswith

df.filter(col("name").endswith("e")).show()

# %% [markdown]
# ##### 2. Sorting Data (orderBy() / sort())

# %%
# Syntax
df.orderBy("salary")

# %%
# Ascending
df.orderBy("salary").show()

# %%
# Descending
from pyspark.sql.functions import col

df.orderBy(col("salary").desc()).show()

# %%
# Multiple Columns
df.orderBy(
    col("dept"),
    col("salary").desc()
).show()


# First sort by department

# Inside each department

# Sort salary descending

# %%
# sort()
    # Exactly same as df.orderBy()
df.sort("salary").show()

# %% [markdown]
# ##### 3. Limiting Rows (limit())

# %%
df.limit(2).show()

# %%
# Highest salary
df.orderBy(col("salary").desc()).limit(1).show()

# %%
# Top 3 Salaries
df.orderBy(
    col("salary").desc()
).limit(3).show()

# %% [markdown]
# ##### 4. Distinct Values
# Used to remove duplicate rows.

# %%
df.distinct()

# %%
df.select("dept").show()

# %%
# Unique departments
df.select("dept").distinct().show()

# %%
# Count distinct values
df.select("dept").distinct().count()

# %%
# Remove duplicate entire rows

df.distinct().show()

# %%
# Remove duplicate based on one column
df.dropDuplicates(["dept"]).show()

# One employee from each department remains.

# %% [markdown]
# | distinct()                    | dropDuplicates()                              |
# | ----------------------------- | --------------------------------------------- |
# | Removes duplicate entire rows | Removes duplicates based on specified columns |
